# %% [markdown]
# # Deliverable 1. Retrieve Weather Data

# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from config import weather_api_key
from citipy import citipy
import requests
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
sample_size = 2000
lats = np.random.uniform(low=-90.000, high=90.000, size=sample_size)
lngs = np.random.uniform(low=-180.000, high=180.000, size=sample_size)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Find the nearest city for each lat and long pair
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then will add to the city list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 776

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
records_count = 1
set_count = 1

# look through all the cities in the list
for i, city in enumerate(cities):
    # group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i>=50):
        set_count += 1
        records_count = 1
    # create endpoint URL 
    city_url = url + "&q=" + city.replace(" ","+")
    
    #log the URL, record and set number and the city
    print(f"Processing record {records_count} of Set {set_count} | {city}")
    records_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing record 1 of Set 1 | ribeira grande
# Processing record 2 of Set 1 | kruisfontein
# Processing record 3 of Set 1 | kasongo
# Processing record 4 of Set 1 | kaitangata
# Processing record 5 of Set 1 | palu
# Processing record 6 of Set 1 | albany
# Processing record 7 of Set 1 | bengkulu
# Processing record 8 of Set 1 | rikitea
# Processing record 9 of Set 1 | mar del plata
# Processing record 10 of Set 1 | bathsheba
# Processing record 11 of Set 1 | port alfred
# Processing record 12 of Set 1 | naze
# Processing record 13 of Set 1 | portland
# Processing record 14 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing record 15 of Set 1 | veraval
# Processing record 16 of Set 1 | marv dasht
# City not found. Skipping...
# Processing record 17 of Set 1 | molnlycke
# Processing record 18 of Set 1 | kapaa
# Processing record 19 of Set 1 | cape town
# Processing record 20 of Set 1 | ketchikan
# Processing record 21 of Set 1 | sao jose da coroa grande
# Processing record 22 of Set 1 | launceston
# Processing record 23 of Set 1 | gorontalo
# Processing record 24 of Set 1 | manaus
# Processing record 25 of Set 1 | vaini
# Processing record 26 of Set 1 | barrow
# Processing record 27 of Set 1 | hasaki
# Processing record 28 of Set 1 | tuktoyaktuk
# Processing record 29 of Set 1 | arraial do cabo
# Processing record 30 of Set 1 | punta arenas
# Processing record 31 of Set 1 | souillac
# Processing record 32 of Set 1 | saint-philippe
# Processing record 33 of Set 1 | jamestown
# Processing record 34 of Set 1 | castro
# Processing record 35 of Set 1 | thompson
# Processing record 36 of Set 1 | ushuaia
# Processing record 37 of Set 1 | necochea
# Processing record 38 of Set 1 | fengzhen
# Processing record 39 of Set 1 | paradwip
# City not found. Skipping...
# Processing record 40 of Set 1 | khanu woralaksaburi
# Processing record 41 of Set 1 | mataura
# Processing record 42 of Set 1 | tasiilaq
# Processing record 43 of Set 1 | mbini
# Processing record 44 of Set 1 | hobart
# Processing record 45 of Set 1 | demyansk
# Processing record 46 of Set 1 | kodiak
# Processing record 47 of Set 1 | yellowknife
# Processing record 48 of Set 1 | amapa
# Processing record 49 of Set 1 | port elizabeth
# Processing record 50 of Set 1 | axim
# Processing record 1 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing record 2 of Set 2 | hamilton
# Processing record 3 of Set 2 | edd
# Processing record 4 of Set 2 | isangel
# Processing record 5 of Set 2 | husavik
# Processing record 6 of Set 2 | manokwari
# Processing record 7 of Set 2 | kotovo
# Processing record 8 of Set 2 | hilo
# Processing record 9 of Set 2 | avarua
# Processing record 10 of Set 2 | hambantota
# Processing record 11 of Set 2 | sola
# Processing record 12 of Set 2 | mahebourg
# Processing record 13 of Set 2 | port arthur
# Processing record 14 of Set 2 | provideniya
# Processing record 15 of Set 2 | takoradi
# Processing record 16 of Set 2 | loandjili
# Processing record 17 of Set 2 | puerto ayora
# Processing record 18 of Set 2 | bluff
# Processing record 19 of Set 2 | bashtanka
# Processing record 20 of Set 2 | bystrice nad pernstejnem
# Processing record 21 of Set 2 | esperance
# Processing record 22 of Set 2 | severo-kurilsk
# Processing record 23 of Set 2 | atuona
# Processing record 24 of Set 2 | bocaiuva
# Processing record 25 of Set 2 | geraldton
# Processing record 26 of Set 2 | yako
# Processing record 27 of Set 2 | zemio
# Processing record 28 of Set 2 | yuxia
# Processing record 29 of Set 2 | borskoye
# Processing record 30 of Set 2 | banjar
# Processing record 31 of Set 2 | labuan
# Processing record 32 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing record 33 of Set 2 | kampong cham
# Processing record 34 of Set 2 | along
# Processing record 35 of Set 2 | butaritari
# Processing record 36 of Set 2 | broome
# Processing record 37 of Set 2 | gurskoye
# City not found. Skipping...
# Processing record 38 of Set 2 | komsomolskiy
# Processing record 39 of Set 2 | cayenne
# Processing record 40 of Set 2 | atambua
# Processing record 41 of Set 2 | busselton
# Processing record 42 of Set 2 | bethel
# Processing record 43 of Set 2 | quthing
# Processing record 44 of Set 2 | hithadhoo
# Processing record 45 of Set 2 | puerto quijarro
# Processing record 46 of Set 2 | chuy
# Processing record 47 of Set 2 | viedma
# Processing record 48 of Set 2 | fianga
# City not found. Skipping...
# Processing record 49 of Set 2 | shestakovo
# Processing record 50 of Set 2 | pont-rouge
# Processing record 1 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing record 2 of Set 3 | ailigandi
# Processing record 3 of Set 3 | agadir
# Processing record 4 of Set 3 | torbay
# Processing record 5 of Set 3 | los llanos de aridane
# Processing record 6 of Set 3 | susurluk
# Processing record 7 of Set 3 | new norfolk
# Processing record 8 of Set 3 | kupino
# Processing record 9 of Set 3 | sakakah
# Processing record 10 of Set 3 | himora
# City not found. Skipping...
# Processing record 11 of Set 3 | dawei
# Processing record 12 of Set 3 | uspantan
# Processing record 13 of Set 3 | vaitupu
# City not found. Skipping...
# Processing record 14 of Set 3 | clyde river
# Processing record 15 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing record 16 of Set 3 | mahon
# Processing record 17 of Set 3 | aranos
# Processing record 18 of Set 3 | geilo
# Processing record 19 of Set 3 | bowen
# Processing record 20 of Set 3 | bairiki
# Processing record 21 of Set 3 | luanda
# Processing record 22 of Set 3 | george
# Processing record 23 of Set 3 | saint-paul
# Processing record 24 of Set 3 | te anau
# Processing record 25 of Set 3 | gdov
# Processing record 26 of Set 3 | upernavik
# Processing record 27 of Set 3 | baybay
# Processing record 28 of Set 3 | ibirapitanga
# Processing record 29 of Set 3 | olafsvik
# Processing record 30 of Set 3 | chernyshevskiy
# Processing record 31 of Set 3 | manta
# Processing record 32 of Set 3 | gravelbourg
# Processing record 33 of Set 3 | yunjinghong
# City not found. Skipping...
# Processing record 34 of Set 3 | goderich
# Processing record 35 of Set 3 | birao
# Processing record 36 of Set 3 | east london
# Processing record 37 of Set 3 | pangai
# Processing record 38 of Set 3 | wangkui
# Processing record 39 of Set 3 | barentsburg
# City not found. Skipping...
# Processing record 40 of Set 3 | thinadhoo
# Processing record 41 of Set 3 | tautira
# Processing record 42 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing record 43 of Set 3 | lugovoy
# Processing record 44 of Set 3 | vasto
# Processing record 45 of Set 3 | juneau
# Processing record 46 of Set 3 | hermanus
# Processing record 47 of Set 3 | sesvete
# Processing record 48 of Set 3 | port blair
# Processing record 49 of Set 3 | lebu
# Processing record 50 of Set 3 | kavaratti
# Processing record 1 of Set 4 | beringovskiy
# Processing record 2 of Set 4 | cabo san lucas
# Processing record 3 of Set 4 | muravlenko
# Processing record 4 of Set 4 | victoria
# Processing record 5 of Set 4 | fortuna
# Processing record 6 of Set 4 | cam ranh
# Processing record 7 of Set 4 | athabasca
# Processing record 8 of Set 4 | colares
# Processing record 9 of Set 4 | mandalgovi
# Processing record 10 of Set 4 | cidreira
# Processing record 11 of Set 4 | codrington
# Processing record 12 of Set 4 | rio gallegos
# Processing record 13 of Set 4 | beloha
# Processing record 14 of Set 4 | ocampo
# Processing record 15 of Set 4 | san cristobal
# Processing record 16 of Set 4 | vahan
# Processing record 17 of Set 4 | waipawa
# Processing record 18 of Set 4 | diamantino
# Processing record 19 of Set 4 | bargal
# City not found. Skipping...
# Processing record 20 of Set 4 | saleaula
# City not found. Skipping...
# Processing record 21 of Set 4 | pierre
# Processing record 22 of Set 4 | tuatapere
# Processing record 23 of Set 4 | balykshi
# Processing record 24 of Set 4 | licheng
# Processing record 25 of Set 4 | nikolskoye
# Processing record 26 of Set 4 | asau
# Processing record 27 of Set 4 | bredasdorp
# Processing record 28 of Set 4 | lasa
# Processing record 29 of Set 4 | anadyr
# Processing record 30 of Set 4 | makakilo city
# Processing record 31 of Set 4 | palmer
# Processing record 32 of Set 4 | sembakung
# Processing record 33 of Set 4 | saint george
# Processing record 34 of Set 4 | yakeshi
# Processing record 35 of Set 4 | puerto narino
# Processing record 36 of Set 4 | georgetown
# Processing record 37 of Set 4 | kieta
# Processing record 38 of Set 4 | nome
# Processing record 39 of Set 4 | toungoo
# City not found. Skipping...
# Processing record 40 of Set 4 | belushya guba
# City not found. Skipping...
# Processing record 41 of Set 4 | west bay
# Processing record 42 of Set 4 | zyryanka
# Processing record 43 of Set 4 | nuuk
# Processing record 44 of Set 4 | teluknaga
# Processing record 45 of Set 4 | sobolevo
# Processing record 46 of Set 4 | dingle
# Processing record 47 of Set 4 | kikwit
# Processing record 48 of Set 4 | dikson
# Processing record 49 of Set 4 | fuerte olimpo
# Processing record 50 of Set 4 | saskylakh
# Processing record 1 of Set 5 | severo-yeniseyskiy
# Processing record 2 of Set 5 | college
# Processing record 3 of Set 5 | viligili
# City not found. Skipping...
# Processing record 4 of Set 5 | nanakuli
# Processing record 5 of Set 5 | poopo
# Processing record 6 of Set 5 | merauke
# Processing record 7 of Set 5 | talnakh
# Processing record 8 of Set 5 | fengrun
# Processing record 9 of Set 5 | ahipara
# Processing record 10 of Set 5 | airai
# Processing record 11 of Set 5 | abalak
# Processing record 12 of Set 5 | zhanaozen
# Processing record 13 of Set 5 | iqaluit
# Processing record 14 of Set 5 | severnoye
# Processing record 15 of Set 5 | saint-louis
# Processing record 16 of Set 5 | vila
# Processing record 17 of Set 5 | puerto escondido
# Processing record 18 of Set 5 | luderitz
# Processing record 19 of Set 5 | derzhavinsk
# Processing record 20 of Set 5 | vila velha
# Processing record 21 of Set 5 | laguna
# Processing record 22 of Set 5 | ancud
# Processing record 23 of Set 5 | saryshagan
# City not found. Skipping...
# Processing record 24 of Set 5 | karakendzha
# City not found. Skipping...
# Processing record 25 of Set 5 | ceres
# Processing record 26 of Set 5 | calbuco
# Processing record 27 of Set 5 | filadelfia
# Processing record 28 of Set 5 | alice springs
# Processing record 29 of Set 5 | faya
# Processing record 30 of Set 5 | kavieng
# Processing record 31 of Set 5 | abu dhabi
# Processing record 32 of Set 5 | faanui
# Processing record 33 of Set 5 | wawa
# Processing record 34 of Set 5 | lerwick
# Processing record 35 of Set 5 | grindavik
# Processing record 36 of Set 5 | grand river south east
# City not found. Skipping...
# Processing record 37 of Set 5 | coahuayana
# Processing record 38 of Set 5 | gizo
# Processing record 39 of Set 5 | wahran
# City not found. Skipping...
# Processing record 40 of Set 5 | sikasso
# Processing record 41 of Set 5 | vila franca do campo
# Processing record 42 of Set 5 | xingyi
# Processing record 43 of Set 5 | hansot
# Processing record 44 of Set 5 | srednekolymsk
# Processing record 45 of Set 5 | kahului
# Processing record 46 of Set 5 | aden
# Processing record 47 of Set 5 | kamina
# Processing record 48 of Set 5 | bakuriani
# Processing record 49 of Set 5 | tura
# Processing record 50 of Set 5 | skagastrond
# City not found. Skipping...
# Processing record 1 of Set 6 | behshahr
# Processing record 2 of Set 6 | elizabeth city
# Processing record 3 of Set 6 | acapulco
# Processing record 4 of Set 6 | mattru
# Processing record 5 of Set 6 | gwadar
# Processing record 6 of Set 6 | tsihombe
# City not found. Skipping...
# Processing record 7 of Set 6 | xai-xai
# Processing record 8 of Set 6 | hofn
# Processing record 9 of Set 6 | la huacana
# Processing record 10 of Set 6 | tecoanapa
# Processing record 11 of Set 6 | weinan
# Processing record 12 of Set 6 | haibowan
# City not found. Skipping...
# Processing record 13 of Set 6 | kaniama
# Processing record 14 of Set 6 | jaguarao
# Processing record 15 of Set 6 | shetpe
# Processing record 16 of Set 6 | taolanaro
# City not found. Skipping...
# Processing record 17 of Set 6 | jalu
# Processing record 18 of Set 6 | gazanjyk
# Processing record 19 of Set 6 | fountain
# Processing record 20 of Set 6 | polunochnoye
# Processing record 21 of Set 6 | mindszent
# Processing record 22 of Set 6 | port lincoln
# Processing record 23 of Set 6 | maarianhamina
# Processing record 24 of Set 6 | aklavik
# Processing record 25 of Set 6 | camacha
# Processing record 26 of Set 6 | alta floresta
# Processing record 27 of Set 6 | zaterechnyy
# Processing record 28 of Set 6 | birjand
# Processing record 29 of Set 6 | san luis
# Processing record 30 of Set 6 | ambon
# Processing record 31 of Set 6 | shache
# Processing record 32 of Set 6 | ponta do sol
# Processing record 33 of Set 6 | leningradskiy
# Processing record 34 of Set 6 | hoa binh
# Processing record 35 of Set 6 | mogadishu
# Processing record 36 of Set 6 | alofi
# Processing record 37 of Set 6 | tiksi
# Processing record 38 of Set 6 | glendive
# Processing record 39 of Set 6 | kuche
# City not found. Skipping...
# Processing record 40 of Set 6 | olga
# Processing record 41 of Set 6 | kenai
# Processing record 42 of Set 6 | comodoro rivadavia
# Processing record 43 of Set 6 | nemuro
# Processing record 44 of Set 6 | bara
# Processing record 45 of Set 6 | burica
# City not found. Skipping...
# Processing record 46 of Set 6 | charters towers
# Processing record 47 of Set 6 | ahumada
# City not found. Skipping...
# Processing record 48 of Set 6 | adrar
# Processing record 49 of Set 6 | meyungs
# City not found. Skipping...
# Processing record 50 of Set 6 | ixtapa
# Processing record 1 of Set 7 | fairbanks
# Processing record 2 of Set 7 | palana
# Processing record 3 of Set 7 | formosa
# Processing record 4 of Set 7 | margate
# Processing record 5 of Set 7 | constitucion
# Processing record 6 of Set 7 | rawson
# Processing record 7 of Set 7 | victor harbor
# Processing record 8 of Set 7 | luba
# Processing record 9 of Set 7 | coihaique
# Processing record 10 of Set 7 | pevek
# Processing record 11 of Set 7 | payo
# Processing record 12 of Set 7 | san patricio
# Processing record 13 of Set 7 | trois-pistoles
# City not found. Skipping...
# Processing record 14 of Set 7 | utinga
# Processing record 15 of Set 7 | narsaq
# Processing record 16 of Set 7 | monrovia
# Processing record 17 of Set 7 | ambilobe
# Processing record 18 of Set 7 | pandan
# Processing record 19 of Set 7 | aksarka
# Processing record 20 of Set 7 | amderma
# City not found. Skipping...
# Processing record 21 of Set 7 | bubaque
# Processing record 22 of Set 7 | nyurba
# Processing record 23 of Set 7 | saint-denis
# Processing record 24 of Set 7 | lompoc
# Processing record 25 of Set 7 | fukue
# Processing record 26 of Set 7 | gillette
# Processing record 27 of Set 7 | buala
# Processing record 28 of Set 7 | chokurdakh
# Processing record 29 of Set 7 | padang
# Processing record 30 of Set 7 | yuci
# Processing record 31 of Set 7 | biak
# Processing record 32 of Set 7 | gola bazar
# Processing record 33 of Set 7 | amuntai
# Processing record 34 of Set 7 | sann
# Processing record 35 of Set 7 | syracuse
# Processing record 36 of Set 7 | grand bank
# Processing record 37 of Set 7 | siparia
# Processing record 38 of Set 7 | kemin
# Processing record 39 of Set 7 | nsoko
# Processing record 40 of Set 7 | ithaca
# Processing record 41 of Set 7 | vanimo
# Processing record 42 of Set 7 | kanniyakumari
# Processing record 43 of Set 7 | maamba
# Processing record 44 of Set 7 | mazagao
# Processing record 45 of Set 7 | luwingu
# Processing record 46 of Set 7 | samusu
# City not found. Skipping...
# Processing record 47 of Set 7 | peniche
# Processing record 48 of Set 7 | sao filipe
# Processing record 49 of Set 7 | santiago de cao
# Processing record 50 of Set 7 | longyearbyen
# Processing record 1 of Set 8 | glens falls
# Processing record 2 of Set 8 | bay-khaak
# Processing record 3 of Set 8 | ust-tsilma
# Processing record 4 of Set 8 | norman wells
# Processing record 5 of Set 8 | ciudad bolivar
# Processing record 6 of Set 8 | san juan del sur
# Processing record 7 of Set 8 | louisbourg
# City not found. Skipping...
# Processing record 8 of Set 8 | nanortalik
# Processing record 9 of Set 8 | praia da vitoria
# Processing record 10 of Set 8 | cap malheureux
# Processing record 11 of Set 8 | lithakia
# Processing record 12 of Set 8 | deputatskiy
# Processing record 13 of Set 8 | potosi
# Processing record 14 of Set 8 | lata
# Processing record 15 of Set 8 | three hills
# Processing record 16 of Set 8 | guane
# Processing record 17 of Set 8 | meadow lake
# Processing record 18 of Set 8 | bambous virieux
# Processing record 19 of Set 8 | ostrovnoy
# Processing record 20 of Set 8 | guanare
# Processing record 21 of Set 8 | saint-felicien
# Processing record 22 of Set 8 | menongue
# Processing record 23 of Set 8 | marcona
# City not found. Skipping...
# Processing record 24 of Set 8 | kindia
# Processing record 25 of Set 8 | abiy adi
# City not found. Skipping...
# Processing record 26 of Set 8 | itacare
# Processing record 27 of Set 8 | lolua
# City not found. Skipping...
# Processing record 28 of Set 8 | robertsport
# Processing record 29 of Set 8 | surt
# Processing record 30 of Set 8 | mandalay
# Processing record 31 of Set 8 | pangody
# Processing record 32 of Set 8 | wenatchee
# Processing record 33 of Set 8 | elko
# Processing record 34 of Set 8 | tumannyy
# City not found. Skipping...
# Processing record 35 of Set 8 | pontianak
# Processing record 36 of Set 8 | carpinteria
# Processing record 37 of Set 8 | havelock
# Processing record 38 of Set 8 | sungairaya
# Processing record 39 of Set 8 | salalah
# Processing record 40 of Set 8 | brae
# Processing record 41 of Set 8 | ventspils
# Processing record 42 of Set 8 | batemans bay
# Processing record 43 of Set 8 | mutsamudu
# City not found. Skipping...
# Processing record 44 of Set 8 | beidao
# Processing record 45 of Set 8 | calderitas
# Processing record 46 of Set 8 | jawhar
# Processing record 47 of Set 8 | saint-augustin
# Processing record 48 of Set 8 | qaanaaq
# Processing record 49 of Set 8 | san quintin
# Processing record 50 of Set 8 | ilulissat
# Processing record 1 of Set 9 | caravelas
# Processing record 2 of Set 9 | ahuimanu
# Processing record 3 of Set 9 | acarau
# Processing record 4 of Set 9 | lagoa
# Processing record 5 of Set 9 | bollnas
# Processing record 6 of Set 9 | katsuura
# Processing record 7 of Set 9 | khatanga
# Processing record 8 of Set 9 | teya
# Processing record 9 of Set 9 | labrea
# Processing record 10 of Set 9 | santa maria
# Processing record 11 of Set 9 | millau
# Processing record 12 of Set 9 | puerto colombia
# Processing record 13 of Set 9 | brooks
# Processing record 14 of Set 9 | champerico
# Processing record 15 of Set 9 | tabory
# Processing record 16 of Set 9 | vallenar
# Processing record 17 of Set 9 | saint-francois
# Processing record 18 of Set 9 | phuket
# Processing record 19 of Set 9 | la rioja
# Processing record 20 of Set 9 | mangan
# Processing record 21 of Set 9 | araouane
# Processing record 22 of Set 9 | villazon
# Processing record 23 of Set 9 | namatanai
# Processing record 24 of Set 9 | port-gentil
# Processing record 25 of Set 9 | angangxi
# City not found. Skipping...
# Processing record 26 of Set 9 | chapleau
# Processing record 27 of Set 9 | rawlins
# Processing record 28 of Set 9 | oskaloosa
# Processing record 29 of Set 9 | fernley
# Processing record 30 of Set 9 | udachnyy
# Processing record 31 of Set 9 | gunjur
# Processing record 32 of Set 9 | tabou
# Processing record 33 of Set 9 | rostock
# Processing record 34 of Set 9 | linjiang
# Processing record 35 of Set 9 | la ronge
# Processing record 36 of Set 9 | vrangel
# Processing record 37 of Set 9 | karratha
# Processing record 38 of Set 9 | mamlyutka
# Processing record 39 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing record 40 of Set 9 | ust-nera
# Processing record 41 of Set 9 | red wing
# Processing record 42 of Set 9 | olinda
# Processing record 43 of Set 9 | morondava
# Processing record 44 of Set 9 | thunder bay
# Processing record 45 of Set 9 | eyl
# Processing record 46 of Set 9 | kamaishi
# Processing record 47 of Set 9 | yukon
# Processing record 48 of Set 9 | saldanha
# Processing record 49 of Set 9 | gujar khan
# Processing record 50 of Set 9 | westport
# Processing record 1 of Set 10 | port-cartier
# Processing record 2 of Set 10 | kasama
# Processing record 3 of Set 10 | orleans
# Processing record 4 of Set 10 | petropavlovsk-kamchatskiy
# Processing record 5 of Set 10 | chulman
# Processing record 6 of Set 10 | road town
# Processing record 7 of Set 10 | sabang
# Processing record 8 of Set 10 | lydenburg
# Processing record 9 of Set 10 | aldan
# Processing record 10 of Set 10 | touros
# Processing record 11 of Set 10 | fomboni
# Processing record 12 of Set 10 | port hedland
# Processing record 13 of Set 10 | sitka
# Processing record 14 of Set 10 | arman
# Processing record 15 of Set 10 | rovaniemi
# Processing record 16 of Set 10 | kabanjahe
# Processing record 17 of Set 10 | tondano
# Processing record 18 of Set 10 | fairlie
# Processing record 19 of Set 10 | santa maria da vitoria
# Processing record 20 of Set 10 | grimshaw
# Processing record 21 of Set 10 | kalavad
# Processing record 22 of Set 10 | cockburn town
# Processing record 23 of Set 10 | yar-sale
# Processing record 24 of Set 10 | capalonga
# Processing record 25 of Set 10 | nicoya
# Processing record 26 of Set 10 | san carlos
# Processing record 27 of Set 10 | itarema
# Processing record 28 of Set 10 | muscat
# Processing record 29 of Set 10 | labuhan
# Processing record 30 of Set 10 | klaksvik
# Processing record 31 of Set 10 | skibbereen
# Processing record 32 of Set 10 | abu kamal
# Processing record 33 of Set 10 | oakdale
# Processing record 34 of Set 10 | jelling
# Processing record 35 of Set 10 | qaqortoq
# Processing record 36 of Set 10 | urumqi
# Processing record 37 of Set 10 | rocha
# Processing record 38 of Set 10 | ganzhou
# Processing record 39 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing record 40 of Set 10 | kodinsk
# Processing record 41 of Set 10 | elat
# Processing record 42 of Set 10 | gobabis
# Processing record 43 of Set 10 | okhotsk
# Processing record 44 of Set 10 | laurel
# Processing record 45 of Set 10 | canillo
# Processing record 46 of Set 10 | boa vista
# Processing record 47 of Set 10 | port hawkesbury
# Processing record 48 of Set 10 | shagonar
# Processing record 49 of Set 10 | richards bay
# Processing record 50 of Set 10 | dalby
# Processing record 1 of Set 11 | cortes
# Processing record 2 of Set 11 | shu
# Processing record 3 of Set 11 | vardo
# Processing record 4 of Set 11 | karaul
# City not found. Skipping...
# Processing record 5 of Set 11 | suntar
# Processing record 6 of Set 11 | yulara
# Processing record 7 of Set 11 | matata
# Processing record 8 of Set 11 | belmonte
# Processing record 9 of Set 11 | kifri
# Processing record 10 of Set 11 | bereda
# Processing record 11 of Set 11 | bourail
# Processing record 12 of Set 11 | velikooktyabrskiy
# Processing record 13 of Set 11 | tazovskiy
# Processing record 14 of Set 11 | shelburne
# Processing record 15 of Set 11 | bardiyah
# Processing record 16 of Set 11 | jega
# Processing record 17 of Set 11 | yagodnoye
# Processing record 18 of Set 11 | sisimiut
# Processing record 19 of Set 11 | walvis bay
# Processing record 20 of Set 11 | amahai
# Processing record 21 of Set 11 | san vicente
# Processing record 22 of Set 11 | guiyang
# Processing record 23 of Set 11 | egvekinot
# Processing record 24 of Set 11 | namibe
# Processing record 25 of Set 11 | rorvik
# Processing record 26 of Set 11 | parana
# Processing record 27 of Set 11 | saint-georges
# Processing record 28 of Set 11 | yurimaguas
# Processing record 29 of Set 11 | cherskiy
# Processing record 30 of Set 11 | guerrero negro
# Processing record 31 of Set 11 | kidal
# Processing record 32 of Set 11 | wattegama
# Processing record 33 of Set 11 | tshikapa
# Processing record 34 of Set 11 | mouzakion
# City not found. Skipping...
# Processing record 35 of Set 11 | sovetsk
# Processing record 36 of Set 11 | erzin
# Processing record 37 of Set 11 | avera
# Processing record 38 of Set 11 | itatskiy
# Processing record 39 of Set 11 | lake city
# Processing record 40 of Set 11 | helmstedt
# Processing record 41 of Set 11 | sao joao da barra
# Processing record 42 of Set 11 | pemangkat
# Processing record 43 of Set 11 | pospelikha
# Processing record 44 of Set 11 | mingyue
# Processing record 45 of Set 11 | basoko
# Processing record 46 of Set 11 | vao
# Processing record 47 of Set 11 | lixourion
# Processing record 48 of Set 11 | kavarna
# Processing record 49 of Set 11 | bousso
# Processing record 50 of Set 11 | vaitape
# Processing record 1 of Set 12 | byron bay
# Processing record 2 of Set 12 | kavali
# Processing record 3 of Set 12 | dicabisagan
# Processing record 4 of Set 12 | deltona
# Processing record 5 of Set 12 | broken hill
# Processing record 6 of Set 12 | changji
# Processing record 7 of Set 12 | filingue
# Processing record 8 of Set 12 | houma
# Processing record 9 of Set 12 | porto novo
# Processing record 10 of Set 12 | vestmanna
# Processing record 11 of Set 12 | porirua
# Processing record 12 of Set 12 | gat
# Processing record 13 of Set 12 | pauini
# Processing record 14 of Set 12 | najran
# Processing record 15 of Set 12 | kambove
# Processing record 16 of Set 12 | kerki
# City not found. Skipping...
# Processing record 17 of Set 12 | karpathos
# Processing record 18 of Set 12 | victoria point
# Processing record 19 of Set 12 | arlit
# Processing record 20 of Set 12 | zhanatas
# City not found. Skipping...
# Processing record 21 of Set 12 | isla vista
# Processing record 22 of Set 12 | tabiauea
# City not found. Skipping...
# Processing record 23 of Set 12 | mapiri
# Processing record 24 of Set 12 | carahue
# Processing record 25 of Set 12 | kupang
# Processing record 26 of Set 12 | kegayli
# City not found. Skipping...
# Processing record 27 of Set 12 | shenjiamen
# Processing record 28 of Set 12 | mocuba
# Processing record 29 of Set 12 | mayakonda
# Processing record 30 of Set 12 | union
# Processing record 31 of Set 12 | flinders
# Processing record 32 of Set 12 | wankaner
# Processing record 33 of Set 12 | carnarvon
# Processing record 34 of Set 12 | usta muhammad
# Processing record 35 of Set 12 | murray bridge
# Processing record 36 of Set 12 | razole
# Processing record 37 of Set 12 | cabedelo
# Processing record 38 of Set 12 | stromness
# Processing record 39 of Set 12 | ulundi
# Processing record 40 of Set 12 | parati
# Processing record 41 of Set 12 | zyryanovsk
# Processing record 42 of Set 12 | binga
# Processing record 43 of Set 12 | hay river
# Processing record 44 of Set 12 | bontang
# Processing record 45 of Set 12 | uporovo
# Processing record 46 of Set 12 | vendome
# Processing record 47 of Set 12 | lavrentiya
# Processing record 48 of Set 12 | jizan
# Processing record 49 of Set 12 | sept-iles
# Processing record 50 of Set 12 | maloy
# Processing record 1 of Set 13 | sochi
# Processing record 2 of Set 13 | rawannawi
# City not found. Skipping...
# Processing record 3 of Set 13 | aksha
# Processing record 4 of Set 13 | opuwo
# Processing record 5 of Set 13 | nouakchott
# Processing record 6 of Set 13 | ponta delgada
# Processing record 7 of Set 13 | towada
# Processing record 8 of Set 13 | abu samrah
# Processing record 9 of Set 13 | sangar
# Processing record 10 of Set 13 | nelson bay
# Processing record 11 of Set 13 | luwuk
# Processing record 12 of Set 13 | sur
# Processing record 13 of Set 13 | dillon
# Processing record 14 of Set 13 | aksu
# Processing record 15 of Set 13 | bonavista
# Processing record 16 of Set 13 | ozubulu
# Processing record 17 of Set 13 | vulcan
# Processing record 18 of Set 13 | assiniboia
# Processing record 19 of Set 13 | doha
# Processing record 20 of Set 13 | esso
# Processing record 21 of Set 13 | mponela
# Processing record 22 of Set 13 | pisco
# Processing record 23 of Set 13 | puqi
# Processing record 24 of Set 13 | pilao arcado
# City not found. Skipping...
# Processing record 25 of Set 13 | timmins
# Processing record 26 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing record 27 of Set 13 | talara
# Processing record 28 of Set 13 | lorengau
# Processing record 29 of Set 13 | kaeo
# Processing record 30 of Set 13 | vostok
# Processing record 31 of Set 13 | san juan
# Processing record 32 of Set 13 | buqayq
# City not found. Skipping...
# Processing record 33 of Set 13 | desaguadero
# Processing record 34 of Set 13 | muli
# Processing record 35 of Set 13 | saint anthony
# Processing record 36 of Set 13 | meulaboh
# Processing record 37 of Set 13 | qujing
# Processing record 38 of Set 13 | samana
# Processing record 39 of Set 13 | baijiantan
# Processing record 40 of Set 13 | vodstroy
# Processing record 41 of Set 13 | nosy varika
# Processing record 42 of Set 13 | amboasary
# Processing record 43 of Set 13 | nizhniy kuranakh
# Processing record 44 of Set 13 | pindwara
# Processing record 45 of Set 13 | lecce
# Processing record 46 of Set 13 | devils lake
# Processing record 47 of Set 13 | matara
# Processing record 48 of Set 13 | nkayi
# Processing record 49 of Set 13 | tottori
# Processing record 50 of Set 13 | dunedin
# Processing record 1 of Set 14 | bantry
# Processing record 2 of Set 14 | zhigansk
# Processing record 3 of Set 14 | coquimbo
# Processing record 4 of Set 14 | mvuma
# Processing record 5 of Set 14 | visby
# Processing record 6 of Set 14 | kapit
# Processing record 7 of Set 14 | waitati
# Processing record 8 of Set 14 | berlevag
# Processing record 9 of Set 14 | yangambi
# Processing record 10 of Set 14 | aykhal
# Processing record 11 of Set 14 | san vito dei normanni
# Processing record 12 of Set 14 | miraflores
# Processing record 13 of Set 14 | tamiahua
# Processing record 14 of Set 14 | zaykovo
# Processing record 15 of Set 14 | port hardy
# Processing record 16 of Set 14 | manado
# Processing record 17 of Set 14 | hualmay
# Processing record 18 of Set 14 | pacific grove
# Processing record 19 of Set 14 | borogontsy
# Processing record 20 of Set 14 | anchorage
# Processing record 21 of Set 14 | kushnarenkovo
# Processing record 22 of Set 14 | hualahuises
# Processing record 23 of Set 14 | taiyuan
# Processing record 24 of Set 14 | emerald
# Processing record 25 of Set 14 | prince rupert
# Processing record 26 of Set 14 | westerland
# Processing record 27 of Set 14 | illapel
# Processing record 28 of Set 14 | stuttgart
# Processing record 29 of Set 14 | half moon bay
# Processing record 30 of Set 14 | hoquiam
# Processing record 31 of Set 14 | benevento
# Processing record 32 of Set 14 | skalistyy
# City not found. Skipping...
# Processing record 33 of Set 14 | amsterdam
# Processing record 34 of Set 14 | grand gaube
# Processing record 35 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing record 36 of Set 14 | salvador
# Processing record 37 of Set 14 | mana
# Processing record 38 of Set 14 | san jose
# Processing record 39 of Set 14 | preobrazheniye
# Processing record 40 of Set 14 | nsanje
# Processing record 41 of Set 14 | izhma
# Processing record 42 of Set 14 | padilla
# Processing record 43 of Set 14 | malakal
# Processing record 44 of Set 14 | nioro
# Processing record 45 of Set 14 | qandahar
# City not found. Skipping...
# Processing record 46 of Set 14 | erdenet
# Processing record 47 of Set 14 | rumonge
# Processing record 48 of Set 14 | puerto carreno
# Processing record 49 of Set 14 | atbasar
# Processing record 50 of Set 14 | cruz alta
# Processing record 1 of Set 15 | huilong
# Processing record 2 of Set 15 | pundaguitan
# Processing record 3 of Set 15 | pyapon
# Processing record 4 of Set 15 | welkom
# Processing record 5 of Set 15 | webuye
# Processing record 6 of Set 15 | hervey bay
# Processing record 7 of Set 15 | buchanan
# Processing record 8 of Set 15 | kishi
# Processing record 9 of Set 15 | karakol
# Processing record 10 of Set 15 | jacareacanga
# Processing record 11 of Set 15 | erikoussa
# City not found. Skipping...
# Processing record 12 of Set 15 | shubarshi
# Processing record 13 of Set 15 | mashhad
# Processing record 14 of Set 15 | stokmarknes
# Processing record 15 of Set 15 | kawai
# Processing record 16 of Set 15 | zhumadian
# Processing record 17 of Set 15 | grand centre
# City not found. Skipping...
# Processing record 18 of Set 15 | tehachapi
# Processing record 19 of Set 15 | yaan
# Processing record 20 of Set 15 | nabire
# Processing record 21 of Set 15 | tricase
# Processing record 22 of Set 15 | anton lizardo
# Processing record 23 of Set 15 | lake cowichan
# Processing record 24 of Set 15 | manavalakurichi
# Processing record 25 of Set 15 | dudinka
# Processing record 26 of Set 15 | coffs harbour
# Processing record 27 of Set 15 | diego de almagro
# Processing record 28 of Set 15 | tungkang
# City not found. Skipping...
# Processing record 29 of Set 15 | gewane
# Processing record 30 of Set 15 | north platte
# Processing record 31 of Set 15 | linxia
# Processing record 32 of Set 15 | muskogee
# Processing record 33 of Set 15 | naugarzan
# City not found. Skipping...
# Processing record 34 of Set 15 | duzici
# City not found. Skipping...
# Processing record 35 of Set 15 | kandrian
# Processing record 36 of Set 15 | belomorsk
# Processing record 37 of Set 15 | buon me thuot
# City not found. Skipping...
# Processing record 38 of Set 15 | carauari
# Processing record 39 of Set 15 | marsh harbour
# Processing record 40 of Set 15 | masalli
# Processing record 41 of Set 15 | kushmurun
# Processing record 42 of Set 15 | nogliki
# Processing record 43 of Set 15 | isilkul
# Processing record 44 of Set 15 | hami
# Processing record 45 of Set 15 | iskateley
# Processing record 46 of Set 15 | sungaipenuh
# Processing record 47 of Set 15 | palmas
# Processing record 48 of Set 15 | changping
# Processing record 49 of Set 15 | jabinyanah
# Processing record 50 of Set 15 | aflu
# City not found. Skipping...
# Processing record 1 of Set 16 | baruun-urt
# Processing record 2 of Set 16 | azimur
# City not found. Skipping...
# Processing record 3 of Set 16 | marienburg
# Processing record 4 of Set 16 | hays
# Processing record 5 of Set 16 | goure
# Processing record 6 of Set 16 | batken
# Processing record 7 of Set 16 | buraydah
# Processing record 8 of Set 16 | shubarkuduk
# Processing record 9 of Set 16 | xuddur
# Processing record 10 of Set 16 | san-pedro
# Processing record 11 of Set 16 | kem
# Processing record 12 of Set 16 | nara
# Processing record 13 of Set 16 | argalasti
# Processing record 14 of Set 16 | valdivia
# Processing record 15 of Set 16 | letlhakane
# Processing record 16 of Set 16 | wencheng
# Processing record 17 of Set 16 | kibala
# Processing record 18 of Set 16 | bambanglipuro
# Processing record 19 of Set 16 | show low
# Processing record 20 of Set 16 | hovd
# Processing record 21 of Set 16 | kungurtug
# Processing record 22 of Set 16 | cururupu
# Processing record 23 of Set 16 | shingu
# Processing record 24 of Set 16 | glucholazy
# Processing record 25 of Set 16 | saint-pierre
# Processing record 26 of Set 16 | ponerihouen
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 712

# %%
# convert to DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Ribeira Grande      PT  38.5167  -28.7000     64.40        88          75
# 1    Kruisfontein      ZA -34.0033   24.7314     64.00        89         100
# 2         Kasongo      CD  -4.4500   26.6667     71.19        89          47
# 3      Kaitangata      NZ -46.2817  169.8464     55.00        87          99
# 4            Palu      ID  -0.8917  119.8707     74.14        94         100
# 5          Albany      US  42.6001  -73.9662     54.00        66         100
# 6        Bengkulu      ID  -3.8004  102.2655     75.78        87         100
# 7         Rikitea      PF -23.1203 -134.9692     77.86        74          73
# 8   Mar Del Plata      AR -38.0023  -57.5575     75.20        57           0
# 9       Bathsheba      BB  13.2167  -59.5167     86.00        58          40
#
#    Wind Speed Current Description
# 0        8.05       broken clouds
# 1        4.00     overcast clouds
# 2        2.13          light rain
# 3        1.99     overcast clouds
# 4        2.64     overcast clouds
# 5        1.99     overcast clouds
# 6        2.59     overcast clouds
# 7        8.12       broken clouds
# 8       11.50           clear sky
# 9       18.41    scattered clouds

# %%
# create output file (CSV)
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label = "City_ID")
